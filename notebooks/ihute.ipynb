# %%
import os
import sys
import torch
import pandas as pd
import numpy as np
import duckdb
import scipy
from plotly.subplots import make_subplots

# Cell 1: Setup & Configuration

import mlx.core as mx
import plotly.graph_objects as go

# Set random seeds for reproducibility
torch.manual_seed(42)
np.random.seed(42)
mx.random.seed(42)

# Check for Apple Silicon and MLX availability
if not mx.is_available():
    print("Warning: MLX not available. Falling back to CPU.")
    device = torch.device('cpu')
else:
    device = torch.device('mps' if torch.backends.mps.is_available() else 'cpu')

# Configuration constants
TOTAL_BUDGET = 50000  # $50,000/day
NUM_ZONES = 4
DECISION_VARS = 12
OBJECTIVE_DIM = 4

# Paths
RESULTS_DIR = 'results'
os.makedirs(RESULTS_DIR, exist_ok=True)

print("Setup complete. Device:", device)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 21
#      18 mx.random.seed(42)
#      20 # Check for Apple Silicon and MLX availability
# ---> 21 if not mx.is_available():
#      22     print("Warning: MLX not available. Falling back to CPU.")
#      23     device = torch.device('cpu')
#
# TypeError: is_available(): incompatible function arguments. The following argument types are supported:
#     1. is_available(device: mlx.core.Device) -> bool
#
# Invoked with types:
